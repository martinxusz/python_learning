# %% [markdown]
# pandas中有点用法刷新了自己的三观
# - 数组构造

# %%
a={'a':['one']*3 + ['two']*4}
a
# Out:
# {'a': ['one', 'one', 'one', 'two', 'two', 'two', 'two']}

# %% [markdown]
# 上边的数组创建方式算是头次遇见
#
# # Overview of Python Visualization Tools
# http://pbpython.com/visualization-tools-1.html<br>
# http://python.jobbole.com/85601/
# - to enable diagram plotting should use **%matplotlib inline**

# %%
import pandas as pd
# %matplotlib inline

budget = pd.read_csv("mn-budget-detail-2014.csv")
budget = budget.sort('amount',ascending=False)[:10]

pd.options.display.mpl_style = 'default'
budget_plot = budget.plot(kind="bar",x=budget["detail"],
                          title="MN Capital Budget - 2014",
                          legend=False)

# %% [markdown]
# - using **Seaborn** to plot

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

budget = pd.read_csv("mn-budget-detail-2014.csv")
budget = budget.sort('amount',ascending=False)[:10]

sns.set_style("darkgrid")
bar_plot = sns.barplot(x=budget["detail"],y=budget["amount"],
                        palette="muted",
                        order=budget["detail"].tolist())
plt.xticks(rotation=90)
plt.show()

# %%
import pygal
from IPython.display import SVG, HTML

line_chart = pygal.Line()
line_chart.title = 'Browser usage evolution (in %)'
line_chart.x_labels = map(str, range(2002, 2013))
line_chart.add('Firefox', [None, None,    0, 16.6,   25,   31, 36.4, 45.5, 46.3, 42.8, 37.1])
line_chart.add('Chrome',  [None, None, None, None, None, None,    0,  3.9, 10.8, 23.8, 35.3])
line_chart.add('IE',      [85.8, 84.6, 84.7, 74.5,   66, 58.6, 54.7, 44.8, 36.2, 26.6, 20.1])
line_chart.add('Others',  [14.2, 15.4, 15.3,  8.9,    9, 10.4,  8.9,  5.8,  6.7,  6.8,  7.5])
#SVG(line_chart.render())
HTML(line_chart.render())
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.3.1 (lxml) ©Kozea 2012-2016 on 2016-12-31--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7{background-color:rgba(249,249,249,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 path,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 line,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 rect,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .graph{fill:rgba(0,0,0,.87)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 text.no_data{fill:rgba(0,0,0,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .title{fill:rgba(0,0,0,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis .line{stroke:rgba(0,0,0,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis text.major{fill:rgba(0,0,0,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.y .guides:hover .guide.line,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .line-graph .axis.x .guides:hover .guide.line,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .ci{stroke:rgba(0,0,0,.87)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .reactive.active,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .ci .reactive.active{stroke-width:1.5}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .series text{fill:rgba(0,0,0,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .tooltip .value{font-size:1.5em}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .bound{font-size:.5em}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .color-0,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .color-1,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .color-2,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .color-3,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .text-overlay .color-0 text{fill:black}#chart-7a52494e-1dec-4d9c-8fa9 ...
# #chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 text.no_data{text-anchor:middle}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .guide.line{fill:none}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .centered{text-anchor:middle}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .title{text-anchor:middle}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .legends .legend text{fill-opacity:1}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.x text{text-anchor:middle}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.y text{text-anchor:end}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.y text[transform].backwards{text-anchor:start}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.y2 text{text-anchor:start}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.y2 text[transform].backwards{text-anchor:end}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis .guide.line{stroke-dasharray:4,4}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis .major.guide.line{stroke-dasharray:6,6}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .horizontal .axis.y .guide.line,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .horizontal .axis.y2 .guide.line,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .vertical .axis.x .guide.line{opacity:0}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .horizontal .axis.always_show .guide.line,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.y .guides:hover .guide.line,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.y2 .guides:hover .guide.line,#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis.x .guides:hover .guide.line{opacity:1}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .axis .guides:hover text{opacity:1}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .nofill{fill:none}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .subtle-fill{fill-opacity:.2}#chart-7a52494e-1dec-4d9c-8fa9-bbcfe4b9a6b7 .dot{stroke-width:1px;fill-opacity:1}#chart-7a52494
