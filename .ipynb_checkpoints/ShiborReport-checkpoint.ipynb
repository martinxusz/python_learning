# %%
import tushare as ts
#参数为空默认取当前年份的数据
df = ts.shibor_data()

# %%
df.sort('date', ascending=False).head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-0e92d04e882c> in <module>()
# ----> 1 df.sort('date', ascending=False).head(3)
#
# AttributeError: 'NoneType' object has no attribute 'sort'

# %%
# %matplotlib inline
df.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-05138ad0d193> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
# ----> 2 df.plot()
#
# AttributeError: 'NoneType' object has no attribute 'plot'

# %%
import pygal
from IPython.display import SVG, HTML

#加上这段后有动画
html_pygal = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
    <!-- ... -->
  </head>
  <body>
    <figure>
      {pygal_render}
    </figure>
  </body>
</html>
"""

line_chart = pygal.Line(interpolate='cubic')
line_chart.title = 'Browser usage evolution (in %)'
line_chart.x_labels = map(str, range(2002, 2013))
line_chart.add('Firefox', [None, None,    0, 16.6,   25,   31, 36.4, 45.5, 46.3, 42.8, 37.1])
line_chart.add('Chrome',  [None, None, None, None, None, None,    0,  3.9, 10.8, 23.8, 35.3])
line_chart.add('IE',      [85.8, 84.6, 84.7, 74.5,   66, 58.6, 54.7, 44.8, 36.2, 26.6, 20.1])
line_chart.add('Others',  [14.2, 15.4, 15.3,  8.9,    9, 10.4,  8.9,  5.8,  6.7,  6.8,  7.5])
#SVG(line_chart.render())
#HTML(line_chart.render())
HTML(html_pygal.format(pygal_render=line_chart.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-d6c296e7-c37a-4656-81f7-4a376d339ca0" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.3.1 (lxml) ©Kozea 2012-2016 on 2017-01-01--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d6c296e7-c37a-4656-81f7-4a376d339ca0{background-color:rgba(249,249,249,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 path,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 line,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 rect,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .graph{fill:rgba(0,0,0,.87)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 text.no_data{fill:rgba(0,0,0,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .title{fill:rgba(0,0,0,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis .line{stroke:rgba(0,0,0,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis text.major{fill:rgba(0,0,0,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.y .guides:hover .guide.line,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .line-graph .axis.x .guides:hover .guide.line,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .ci{stroke:rgba(0,0,0,.87)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .reactive.active,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .ci .reactive.active{stroke-width:1.5}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .series text{fill:rgba(0,0,0,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .tooltip .value{font-size:1.5em}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .bound{font-size:.5em}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .color-0,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .color-1,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .color-2,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .color-3,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .text-overlay .color-0 text{fill:black}#chart-d6c296e7-c37a-4656-81f7 ...
# #chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 text.no_data{text-anchor:middle}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .guide.line{fill:none}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .centered{text-anchor:middle}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .title{text-anchor:middle}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .legends .legend text{fill-opacity:1}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.x text{text-anchor:middle}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.y text{text-anchor:end}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.y text[transform].backwards{text-anchor:start}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.y2 text{text-anchor:start}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.y2 text[transform].backwards{text-anchor:end}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis .guide.line{stroke-dasharray:4,4}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis .major.guide.line{stroke-dasharray:6,6}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .horizontal .axis.y .guide.line,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .horizontal .axis.y2 .guide.line,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .vertical .axis.x .guide.line{opacity:0}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .horizontal .axis.always_show .guide.line,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.y .guides:hover .guide.line,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.y2 .guides:hover .guide.line,#chart-d6c296e7-c37a-4656-81f7-4a376d339ca0 .axis.x .guides:hover .guide.line{opacity:1}#
